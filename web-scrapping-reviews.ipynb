# %%
import googlemaps
import pandas as pd

# %%
gmaps = googlemaps.Client(key='AIzaSyBUA_o4n7WjFJI9AoXXXnp8GCUzcyk36X4')

# %%
def getPlaceWithReviews(list):
    a = [p for p in list['results'] if 'reviews' in gmaps.place(p['place_id'])['result'].keys()]
    return a

def retrieveInformation(pl_with_rev):
    names = []
    total_users_rating = []
    ratings = []
    texts = []
    for place in pl_with_rev:
        place_id = place['place_id']
        info_result = gmaps.place(place_id=place_id)['result']
        reviews = info_result['reviews']
        for r in reviews:
            names.append(info_result['name'])
            total_users_rating.append(info_result['rating']) 
            ratings.append(r['rating'])
            texts.append(r['text'])
    return pd.DataFrame({'names':names, 'overall rating': total_users_rating, 'rating':ratings, 'text':texts})

# %%
place_result = gmaps.places_nearby(location='40.416704, -3.703599', radius=40000, type='cafe')
places_with_reviews = getPlaceWithReviews(place_result)

# %%
df1 = retrieveInformation(places_with_reviews)

# %%
df1
# Out:
#                      names  overall rating  rating  \
# 0      Petit Palace Chueca             4.4       5
# 1      Petit Palace Chueca             4.4       5
# 2      Petit Palace Chueca             4.4       5
# 3      Petit Palace Chueca             4.4       1
# 4      Petit Palace Chueca             4.4       5
# ..                     ...             ...     ...
# 95  East 47 Restaurant-Bar             4.4       5
# 96  East 47 Restaurant-Bar             4.4       5
# 97  East 47 Restaurant-Bar             4.4       5
# 98  East 47 Restaurant-Bar             4.4       5
# 99  East 47 Restaurant-Bar             4.4       5
#
#                                                  text
# 0   I really liked staying at this hotel. The room...
# 1   Very pleasant, inexpensive hotel right off Gra...
# 2   Great experience!!\nThe view of the hotel is a...
# 3   Worst hotel I ever stayed in. Rooms are noisy,...
# 4   Game changer! Welcome back, hotels; see you so...
# ...

# %%
place_result = gmaps.places_nearby(page_token=place_result['next_page_token'])
places_with_reviews = getPlaceWithReviews(place_result)

# %%
df2 = retrieveInformation(places_with_reviews)

# %%
df2
# Out:
#                            names  overall rating  rating  \
# 0   Aqui Pan... y después gloria             4.2       5
# 1   Aqui Pan... y después gloria             4.2       4
# 2   Aqui Pan... y después gloria             4.2       3
# 3   Aqui Pan... y después gloria             4.2       1
# 4   Aqui Pan... y después gloria             4.2       5
# ..                           ...             ...     ...
# 84                   La Rollerie             4.2       4
# 85                   La Rollerie             4.2       4
# 86                   La Rollerie             4.2       5
# 87                   La Rollerie             4.2       5
# 88                   La Rollerie             4.2       3
#
#                                                  text
# 0   So if you are in Plaza Mayor and need a coffee...
# 1                          Great breakfast options :)
# 2   The croissant was rich. I had a problem with t...
# 3   I bought a salad to go. The lettuce was dry (4...
# ...

# %%
final = pd.concat([df1, df2])

# %%
final
# Out:
#                   names  overall rating  rating  \
# 0   Petit Palace Chueca             4.4       5
# 1   Petit Palace Chueca             4.4       5
# 2   Petit Palace Chueca             4.4       5
# 3   Petit Palace Chueca             4.4       1
# 4   Petit Palace Chueca             4.4       5
# ..                  ...             ...     ...
# 84          La Rollerie             4.2       4
# 85          La Rollerie             4.2       4
# 86          La Rollerie             4.2       5
# 87          La Rollerie             4.2       5
# 88          La Rollerie             4.2       3
#
#                                                  text
# 0   I really liked staying at this hotel. The room...
# 1   Very pleasant, inexpensive hotel right off Gra...
# 2   Great experience!!\nThe view of the hotel is a...
# 3   Worst hotel I ever stayed in. Rooms are noisy,...
# 4   Game changer! Welcome back, hotels; see you so...
# ..                                                ...
# ...

# %%
df1.loc[df1.rating < 5]
# Out:
#                                         names  overall rating  rating  \
# 3                         Petit Palace Chueca             4.4       1
# 6                                  Café Gijón             3.6       1
# 7                                  Café Gijón             3.6       1
# 9                                  Café Gijón             3.6       1
# 10                              Costello club             4.1       3
# 11                              Costello club             4.1       1
# 12                              Costello club             4.1       4
# 13                              Costello club             4.1       4
# 14                              Costello club             4.1       3
# 20                            La Llave de Oro             4.5       4
# 22                            La Llave de Oro             4.5       4
# 24                            La Llave de Oro             4.5       4
# ...

# %%
final.loc[final.names == 'Petit Palace Chueca'].rating.mean()
# Out:
# 4.2

# %%
final.names.value_counts()
# Out:
# Starbucks                                    20
# La Rollerie                                  10
# Petit Palace Chueca                           5
# Rodilla                                       5
# Dixie                                         5
# Portosin                                      5
# HanSo Café                                    5
# Astoria                                       5
# Restaurante Los Ángeles                       5
# Café Carmen 17 Bistro                         5
# Café Gijón                                    5
# El Corte Inglés Edificio 4 (Mascotas)         5
# Garden of Salvador Bachiller                  5
# Secret Rooftop Garden                         5
# El Corte Inglés                               5
# Celicioso Callao                              5
# Aqui Pan... y después gloria                  5
# East 47 Restaurant-Bar                        5
# Estación de servicio Cepsa PUENTE SEGOVIA     5
# Pastelería Mallorca                           5
# ...
